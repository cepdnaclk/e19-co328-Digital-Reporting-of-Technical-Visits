# %%
import json

# Load technician profiles
with open('technicians_large.json', 'r') as file:
    technicians = json.load(file)

# Load task descriptions
with open('tasks_large.json', 'r') as file:
    tasks = json.load(file)

# Load historical assignments
with open('historical_assignments.json', 'r') as file:
    historical_assignments = json.load(file)

# %%
# Check for and handle missing values
for technician in technicians:
    if not all(k in technician for k in ["id", "name", "capabilities", "experience", "availability", "location", "performance"]):
        print(f"Missing data in technician: {technician}")

for task in tasks:
    if not all(k in task for k in ["id", "description", "location", "priority", "required_skills", "assigned_technician"]):
        print(f"Missing data in task: {task}")
# Out:
# Missing data in task: {'id': 'TS001', 'description': 'Fix the broken sprinkler system in the garden.', 'location': 'Los Angeles', 'priority': 'Medium', 'assigned_technician': 'T063'}
# Missing data in task: {'id': 'TS002', 'description': 'Install new hand dryers in the public restrooms.', 'location': 'San Jose', 'priority': 'High', 'assigned_technician': 'T001'}
# Missing data in task: {'id': 'TS003', 'description': 'Install new telephone lines in the customer service center.', 'location': 'Phoenix', 'priority': 'High', 'assigned_technician': 'T095'}
# Missing data in task: {'id': 'TS004', 'description': 'Install new shelving units in the warehouse.', 'location': 'San Diego', 'priority': 'Low', 'assigned_technician': 'T008'}
# Missing data in task: {'id': 'TS005', 'description': 'Install new hand dryers in the public restrooms.', 'location': 'Los Angeles', 'priority': 'Low', 'assigned_technician': 'T046'}
# Missing data in task: {'id': 'TS006', 'description': 'Service the air conditioning system in the laboratory.', 'location': 'Phoenix', 'priority': 'High', 'assigned_technician': 'T008'}
# Missing data in task: {'id': 'TS007', 'description': 'Install new backup batteries in the emergency lighting system.', 'location': 'San Antonio', 'priority': 'Medium', 'assigned_technician': 'T019'}
# Missing data in task: {'id': 'TS008', 'description': 'Install a new thermostat in the maintenance office.', 'location': 'San Diego', 'priority': 'High', 'assigned_technician': 'T070'}
# Missing data in task: {'id': 'TS009', 'description': 'Repair the malfunctioning coffee machine in the break room.', 'location': 'San Antonio', 'priority': 'Low', 'assigned_technician': 'T093'}
# Missing data in task: {'id': 'TS010', 'description': 'Install new power strips in the computer lab.', 'location': 'Dallas', 'priority': 'Low', 'assigned_technician': 'T062'}
# Missing data in task: {'id': 'TS011', 'description': 'Install new ergonomic chairs in the training room.', 'location': 'San Antonio', 'priority': 'High', 'assigned_technician': 'T069'}
# Missing data in task: {'id': 'TS012', 'description': 'Install new lighting fixtures in the exhibition hall.', 'location': 'Dallas', 'priority': 'High', 'assigned_technician': 'T035'}
# Missing data in task: {'id': 'TS013', 'description': 'Repair the damaged insulation in the warehouse.', 'location': 'Philadelphia', 'priority': 'Medium', 'assigned_technician': 'T020'}
# Missing data in task: {'id': 'TS014', 'description': 'Inspect and service the fire alarm system.', 'location': 'New York', 'priority': 'High', 'assigned_technician': 'T048'}
# Missing data in task: {'id': 'TS015', 'description': 'Install new protective barriers in the industrial area.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T076'}
# Missing data in task: {'id': 'TS016', 'description': 'Install new emergency exit signs in the building.', 'location': 'San Diego', 'priority': 'High', 'assigned_technician': 'T016'}
# Missing data in task: {'id': 'TS017', 'description': 'Install new ceiling fans in the residential units.', 'location': 'San Jose', 'priority': 'High', 'assigned_technician': 'T010'}
# Missing data in task: {'id': 'TS018', 'description': 'Install new backup batteries in the emergency lighting system.', 'location': 'Chicago', 'priority': 'Medium', 'assigned_technician': 'T086'}
# Missing data in task: {'id': 'TS019', 'description': 'Fix the broken alarm system in the admin office.', 'location': 'San Antonio', 'priority': 'High', 'assigned_technician': 'T008'}
# Missing data in task: {'id': 'TS020', 'description': 'Install new telephone lines in the customer service center.', 'location': 'Phoenix', 'priority': 'High', 'assigned_technician': 'T046'}
# Missing data in task: {'id': 'TS021', 'description': 'Install new office cubicles in the open area.', 'location': 'Los Angeles', 'priority': 'Medium', 'assigned_technician': 'T080'}
# Missing data in task: {'id': 'TS022', 'description': "Fix the broken HVAC unit in the CEO's office.", 'location': 'Dallas', 'priority': 'Medium', 'assigned_technician': 'T020'}
# Missing data in task: {'id': 'TS023', 'description': 'Fix the broken heating unit in the storage warehouse.', 'location': 'Chicago', 'priority': 'Medium', 'assigned_technician': 'T026'}
# Missing data in task: {'id': 'TS024', 'description': 'Install new ergonomic chairs in the training room.', 'location': 'San Jose', 'priority': 'Medium', 'assigned_technician': 'T020'}
# Missing data in task: {'id': 'TS025', 'description': 'Repair the malfunctioning thermostat in the conference room.', 'location': 'Chicago', 'priority': 'Medium', 'assigned_technician': 'T017'}
# Missing data in task: {'id': 'TS026', 'description': 'Install new access control systems at the main gate.', 'location': 'Philadelphia', 'priority': 'High', 'assigned_technician': 'T100'}
# Missing data in task: {'id': 'TS027', 'description': 'Install new flooring in the employee break room.', 'location': 'Philadelphia', 'priority': 'Low', 'assigned_technician': 'T025'}
# Missing data in task: {'id': 'TS028', 'description': 'Fix the broken garage door in the maintenance facility.', 'location': 'San Diego', 'priority': 'Low', 'assigned_technician': 'T012'}
# Missing data in task: {'id': 'TS029', 'description': 'Service the central vacuum system in the hotel.', 'location': 'San Diego', 'priority': 'High', 'assigned_technician': 'T047'}
# Missing data in task: {'id': 'TS030', 'description': 'Install new ergonomic chairs in the training room.', 'location': 'San Diego', 'priority': 'Low', 'assigned_technician': 'T089'}
# Missing data in task: {'id': 'TS031', 'description': 'Install new telephone lines in the customer service center.', 'location': 'Philadelphia', 'priority': 'High', 'assigned_technician': 'T047'}
# Missing data in task: {'id': 'TS032', 'description': 'Service the water filtration system in the cafeteria.', 'location': 'New York', 'priority': 'Low', 'assigned_technician': 'T068'}
# Missing data in task: {'id': 'TS033', 'description': 'Replace the damaged tiles in the restroom.', 'location': 'Dallas', 'priority': 'Medium', 'assigned_technician': 'T009'}
# Missing data in task: {'id': 'TS034', 'description': 'Service the HVAC system on the rooftop.', 'location': 'Chicago', 'priority': 'Medium', 'assigned_technician': 'T060'}
# Missing data in task: {'id': 'TS035', 'description': 'Service the automatic doors in the main entrance.', 'location': 'Chicago', 'priority': 'High', 'assigned_technician': 'T043'}
# Missing data in task: {'id': 'TS036', 'description': 'Install new access control systems at the main gate.', 'location': 'Los Angeles', 'priority': 'Medium', 'assigned_technician': 'T012'}
# Missing data in task: {'id': 'TS037', 'description': 'Service the HVAC system on the rooftop.', 'location': 'Houston', 'priority': 'High', 'assigned_technician': 'T062'}
# Missing data in task: {'id': 'TS038', 'description': 'Fix the broken heating unit in the storage warehouse.', 'location': 'San Jose', 'priority': 'Medium', 'assigned_technician': 'T039'}
# Missing data in task: {'id': 'TS039', 'description': 'Repair the air conditioning unit in the main office.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T057'}
# Missing data in task: {'id': 'TS040', 'description': 'Install new shelving units in the warehouse.', 'location': 'San Antonio', 'priority': 'Medium', 'assigned_technician': 'T076'}
# Missing data in task: {'id': 'TS041', 'description': 'Install new telephone lines in the customer service center.', 'location': 'Chicago', 'priority': 'Low', 'assigned_technician': 'T001'}
# Missing data in task: {'id': 'TS042', 'description': 'Install new ceiling fans in the residential units.', 'location': 'Chicago', 'priority': 'Low', 'assigned_technician': 'T027'}
# Missing data in task: {'id': 'TS043', 'description': 'Paint the exterior walls of the main building.', 'location': 'Houston', 'priority': 'Low', 'assigned_technician': 'T052'}
# Missing data in task: {'id': 'TS044', 'description': 'Install new handrails in the stairwell.', 'location': 'Phoenix', 'priority': 'High', 'assigned_technician': 'T098'}
# Missing data in task: {'id': 'TS045', 'description': 'Fix the broken security gate in the parking lot.', 'location': 'San Jose', 'priority': 'Low', 'assigned_technician': 'T071'}
# Missing data in task: {'id': 'TS046', 'description': 'Install new blinds in the finance department.', 'location': 'San Jose', 'priority': 'High', 'assigned_technician': 'T057'}
# Missing data in task: {'id': 'TS047', 'description': 'Install new network cables in the IT department.', 'location': 'Chicago', 'priority': 'High', 'assigned_technician': 'T010'}
# Missing data in task: {'id': 'TS048', 'description': 'Repair the faulty card readers in the office building.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T012'}
# Missing data in task: {'id': 'TS049', 'description': "Install new signage in the visitor's parking area.", 'location': 'San Diego', 'priority': 'Medium', 'assigned_technician': 'T074'}
# Missing data in task: {'id': 'TS050', 'description': 'Fix the broken security gate in the parking lot.', 'location': 'Dallas', 'priority': 'Low', 'assigned_technician': 'T054'}
# Missing data in task: {'id': 'TS051', 'description': 'Replace the damaged tiles in the restroom.', 'location': 'Phoenix', 'priority': 'High', 'assigned_technician': 'T023'}
# Missing data in task: {'id': 'TS052', 'description': 'Service the elevator control systems in the hotel.', 'location': 'San Antonio', 'priority': 'Low', 'assigned_technician': 'T073'}
# Missing data in task: {'id': 'TS053', 'description': 'Service the power supply units in the server room.', 'location': 'Los Angeles', 'priority': 'Low', 'assigned_technician': 'T081'}
# Missing data in task: {'id': 'TS054', 'description': 'Install new bike racks in the company parking lot.', 'location': 'Dallas', 'priority': 'Low', 'assigned_technician': 'T015'}
# Missing data in task: {'id': 'TS055', 'description': 'Repair the broken door lock in the storage room.', 'location': 'San Antonio', 'priority': 'High', 'assigned_technician': 'T034'}
# Missing data in task: {'id': 'TS056', 'description': 'Install new ergonomic chairs in the training room.', 'location': 'Philadelphia', 'priority': 'High', 'assigned_technician': 'T047'}
# Missing data in task: {'id': 'TS057', 'description': 'Fix the broken water pump in the garden area.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T059'}
# Missing data in task: {'id': 'TS058', 'description': 'Install new carpet in the executive offices.', 'location': 'San Jose', 'priority': 'Low', 'assigned_technician': 'T057'}
# Missing data in task: {'id': 'TS059', 'description': 'Repair the leaky faucet in the employee lounge.', 'location': 'Dallas', 'priority': 'High', 'assigned_technician': 'T094'}
# Missing data in task: {'id': 'TS060', 'description': 'Install new ceiling fans in the residential units.', 'location': 'San Diego', 'priority': 'Medium', 'assigned_technician': 'T049'}
# Missing data in task: {'id': 'TS061', 'description': 'Service the air conditioning system in the laboratory.', 'location': 'Chicago', 'priority': 'Medium', 'assigned_technician': 'T016'}
# Missing data in task: {'id': 'TS062', 'description': 'Service the power supply units in the server room.', 'location': 'Chicago', 'priority': 'High', 'assigned_technician': 'T027'}
# Missing data in task: {'id': 'TS063', 'description': 'Service the HVAC ducts in the admin office.', 'location': 'San Antonio', 'priority': 'Medium', 'assigned_technician': 'T014'}
# Missing data in task: {'id': 'TS064', 'description': 'Fix the broken power outlet in the production area.', 'location': 'San Jose', 'priority': 'High', 'assigned_technician': 'T095'}
# Missing data in task: {'id': 'TS065', 'description': 'Fix the broken heating unit in the storage warehouse.', 'location': 'New York', 'priority': 'Medium', 'assigned_technician': 'T058'}
# Missing data in task: {'id': 'TS066', 'description': 'Service the backup generator in the utility room.', 'location': 'San Antonio', 'priority': 'Medium', 'assigned_technician': 'T094'}
# Missing data in task: {'id': 'TS067', 'description': 'Install new bike racks in the company parking lot.', 'location': 'New York', 'priority': 'Low', 'assigned_technician': 'T013'}
# Missing data in task: {'id': 'TS068', 'description': 'Install new power strips in the computer lab.', 'location': 'Phoenix', 'priority': 'Low', 'assigned_technician': 'T012'}
# Missing data in task: {'id': 'TS069', 'description': 'Service the main boiler in the mechanical room.', 'location': 'Los Angeles', 'priority': 'Medium', 'assigned_technician': 'T018'}
# Missing data in task: {'id': 'TS070', 'description': 'Repair the leaking roof on the warehouse.', 'location': 'Houston', 'priority': 'High', 'assigned_technician': 'T007'}
# Missing data in task: {'id': 'TS071', 'description': 'Repair the faulty card readers in the office building.', 'location': 'San Jose', 'priority': 'Low', 'assigned_technician': 'T093'}
# Missing data in task: {'id': 'TS072', 'description': 'Service the water filtration system in the cafeteria.', 'location': 'Los Angeles', 'priority': 'Medium', 'assigned_technician': 'T029'}
# Missing data in task: {'id': 'TS073', 'description': 'Inspect and service the fire alarm system.', 'location': 'San Jose', 'priority': 'High', 'assigned_technician': 'T086'}
# Missing data in task: {'id': 'TS074', 'description': 'Install new flooring in the employee break room.', 'location': 'Dallas', 'priority': 'Low', 'assigned_technician': 'T065'}
# Missing data in task: {'id': 'TS075', 'description': 'Fix the broken sprinkler heads in the garden.', 'location': 'New York', 'priority': 'High', 'assigned_technician': 'T097'}
# Missing data in task: {'id': 'TS076', 'description': 'Install new network switches in the data center.', 'location': 'San Diego', 'priority': 'Medium', 'assigned_technician': 'T081'}
# Missing data in task: {'id': 'TS077', 'description': 'Fix the broken power outlet in the production area.', 'location': 'New York', 'priority': 'Low', 'assigned_technician': 'T046'}
# Missing data in task: {'id': 'TS078', 'description': 'Repair the faulty light switches in the auditorium.', 'location': 'Philadelphia', 'priority': 'Medium', 'assigned_technician': 'T070'}
# Missing data in task: {'id': 'TS079', 'description': 'Repair the faulty card readers in the office building.', 'location': 'San Antonio', 'priority': 'Medium', 'assigned_technician': 'T090'}
# Missing data in task: {'id': 'TS080', 'description': 'Repair the air conditioning unit in the main office.', 'location': 'Philadelphia', 'priority': 'Low', 'assigned_technician': 'T001'}
# Missing data in task: {'id': 'TS081', 'description': 'Service the central heating system in the admin offices.', 'location': 'Houston', 'priority': 'Low', 'assigned_technician': 'T010'}
# Missing data in task: {'id': 'TS082', 'description': 'Fix the broken sprinkler heads in the garden.', 'location': 'Los Angeles', 'priority': 'Medium', 'assigned_technician': 'T082'}
# Missing data in task: {'id': 'TS083', 'description': 'Repair the malfunctioning coffee machine in the break room.', 'location': 'Chicago', 'priority': 'High', 'assigned_technician': 'T026'}
# Missing data in task: {'id': 'TS084', 'description': 'Service the backup generator in the utility room.', 'location': 'Phoenix', 'priority': 'Medium', 'assigned_technician': 'T011'}
# Missing data in task: {'id': 'TS085', 'description': 'Install new energy-efficient windows in the office block.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T034'}
# Missing data in task: {'id': 'TS086', 'description': 'Repair the broken projector in the conference hall.', 'location': 'Los Angeles', 'priority': 'Medium', 'assigned_technician': 'T084'}
# Missing data in task: {'id': 'TS087', 'description': 'Service the HVAC system on the rooftop.', 'location': 'San Diego', 'priority': 'Medium', 'assigned_technician': 'T074'}
# Missing data in task: {'id': 'TS088', 'description': 'Repair the malfunctioning vending machine in the cafeteria.', 'location': 'Phoenix', 'priority': 'High', 'assigned_technician': 'T091'}
# Missing data in task: {'id': 'TS089', 'description': 'Inspect and service the fire alarm system.', 'location': 'Los Angeles', 'priority': 'Low', 'assigned_technician': 'T089'}
# Missing data in task: {'id': 'TS090', 'description': 'Inspect and service the fire alarm system.', 'location': 'San Diego', 'priority': 'Medium', 'assigned_technician': 'T006'}
# Missing data in task: {'id': 'TS091', 'description': 'Service the HVAC system on the rooftop.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T015'}
# Missing data in task: {'id': 'TS092', 'description': 'Install new blinds in the finance department.', 'location': 'Philadelphia', 'priority': 'Medium', 'assigned_technician': 'T061'}
# Missing data in task: {'id': 'TS093', 'description': 'Repair the damaged security camera in the loading dock.', 'location': 'Phoenix', 'priority': 'Medium', 'assigned_technician': 'T039'}
# Missing data in task: {'id': 'TS094', 'description': 'Install new blinds in the finance department.', 'location': 'Dallas', 'priority': 'Low', 'assigned_technician': 'T070'}
# Missing data in task: {'id': 'TS095', 'description': 'Repair the malfunctioning thermostat in the conference room.', 'location': 'Dallas', 'priority': 'High', 'assigned_technician': 'T006'}
# Missing data in task: {'id': 'TS096', 'description': 'Fix the broken heating unit in the storage warehouse.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T084'}
# Missing data in task: {'id': 'TS097', 'description': 'Repair the malfunctioning elevator in the lobby.', 'location': 'San Diego', 'priority': 'Low', 'assigned_technician': 'T055'}
# Missing data in task: {'id': 'TS098', 'description': 'Service the heating system in the dormitories.', 'location': 'San Jose', 'priority': 'Low', 'assigned_technician': 'T086'}
# Missing data in task: {'id': 'TS099', 'description': 'Install new ergonomic chairs in the training room.', 'location': 'Dallas', 'priority': 'Medium', 'assigned_technician': 'T002'}
# Missing data in task: {'id': 'TS100', 'description': 'Install new carpet in the executive offices.', 'location': 'Los Angeles', 'priority': 'High', 'assigned_technician': 'T028'}

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def preprocess(text):
    doc = nlp(text.lower())
    return " ".join(token.lemma_ for token in doc if not token.is_stop and not token.is_punct)

# Preprocess task descriptions and technician capabilities
for task in tasks:
    task['processed_description'] = preprocess(task['description'])

for technician in technicians:
    technician['processed_capabilities'] = preprocess(technician['capabilities'])

# %%
import pandas as pd

# Create DataFrames from JSON data
tasks_df = pd.DataFrame(tasks)
technicians_df = pd.DataFrame(technicians)

# Merge tasks with technicians on 'assigned_technician' and 'id'
combined_df = pd.merge(tasks_df, technicians_df, left_on='assigned_technician', right_on='id', suffixes=('_task', '_tech'), how='left')

# Select relevant columns for the combined dataset
combined_df = combined_df[['id_task', 'processed_description', 'location_task', 'priority', 'name', 'processed_capabilities', 'experience', 'availability', 'location_tech', 'performance','assigned_technician']]

# Rename columns for clarity
combined_df = combined_df.rename(columns={
    'id_task': 'task_id',
    'processed_description': 'task_description',
    'location_task': 'task_location',
    'name': 'technician_name',
    'processed_capabilities': 'technician_capabilities',
    'experience': 'technician_experience',
    'availability': 'technician_availability',
    'location_tech': 'technician_location',
    'assigned_technician': 'technician_id',
})

# Preview combined data
print(combined_df.head())

# Save to a new JSON file if needed
combined_df.to_json('combined_tasks_technicians_preprocessed.json', orient='records', indent=2)
# Out:
#   task_id                                   task_description task_location  \
# 0   TS001                 fix broken sprinkler system garden   Los Angeles
# 1   TS002             install new hand dryer public restroom      San Jose
# 2   TS003  install new telephone line customer service ce...       Phoenix
# 3   TS004                  install new shelve unit warehouse     San Diego
# 4   TS005             install new hand dryer public restroom   Los Angeles
#
#   priority technician_name                            technician_capabilities  \
# 0   Medium  Charles Garcia  specialist setup maintenance home brewing equi...
# 1     High      Kelly Yang  expert diagnose repair hvac system advanced kn...
# 2     High    Matthew Hill  skilled setup maintenance video conferencing s...
# 3      Low   Lucas Collins  adept software installation configuration incl...
# 4      Low      Eric Patel  proficient setup maintenance home fitness equi...
#
#    technician_experience technician_availability technician_location  \
# 0                      6                    Busy             Phoenix
# 1                     17                On Leave             Chicago
# 2                     13               Available              Dallas
# 3                     12               Available             Houston
# 4                     20                On Leave            New York
#
#                                       performance technician_id
# 0  {'success_rate': 0.85, 'feedback_score': 3.72}          T063
# 1   {'success_rate': 0.9, 'feedback_score': 4.28}          T001
# 2  {'success_rate': 0.99, 'feedback_score': 4.66}          T095
# 3  {'success_rate': 0.81, 'feedback_score': 4.57}          T008
# 4  {'success_rate': 0.76, 'feedback_score': 4.62}          T046

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Vectorize text data
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(combined_df['task_description'] + " " + combined_df['technician_capabilities'])
# Ensure technician_id is numeric for model training
label_encoder = LabelEncoder()
combined_df['technician_id_encoded'] = label_encoder.fit_transform(combined_df['technician_id'])

y = combined_df['technician_id_encoded']

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Evaluate model
accuracy = model.score(X_test, y_test)
print(f"Model accuracy: {accuracy:.2f}")
# Out:
# Model accuracy: 0.70

# %%
# Predict technicians for new tasks

# Define new task descriptions
new_tasks = [
    "Install a new HVAC system in the warehouse.",
    "Repair the broken air conditioning unit in the lobby.",
    "Fix the leaking water pipe in the basement.",
    "Upgrade the electrical system in the office building.",
    "Install new carpeting in the conference room.",
    "Repair the faulty fire alarm system in the warehouse.",
    "Service the backup generator in the utility room.",
    "Install new LED lighting in the parking lot.",
    "Fix the broken door lock in the storage area.",
    "Inspect and service the ventilation system in the factory."
]

# Predict technicians for new tasks and show suitability percentage
predictions = []
for new_task in new_tasks:
    new_task_preprocessed = preprocess(new_task)
    new_task_vector = vectorizer.transform([new_task_preprocessed])
    predicted_probabilities = model.predict_proba(new_task_vector)
    predicted_technician_encoded = model.predict(new_task_vector)[0]
    predicted_technician_id = label_encoder.inverse_transform([predicted_technician_encoded])[0]
    predicted_technician = technicians_df[technicians_df["id"] == predicted_technician_id].iloc[0]
    suitability_percentage = predicted_probabilities[0][predicted_technician_encoded] * 100
    predictions.append({
        "task_description": new_task,
        "assigned_technician": predicted_technician['name'],
        "suitability_percentage": suitability_percentage,
        "technician capabilities": predicted_technician['capabilities']
    })

# Display predictions
for prediction in predictions:
    print(f"Task: {prediction['task_description']}")
    print(f"Assigned Technician: {prediction['assigned_technician']}")
    print(f"Suitability: {prediction['suitability_percentage']:.2f}%")
    print(f"Technician Capabilities: {prediction['technician capabilities']}")
    print()
# Out:
# Task: Install a new HVAC system in the warehouse.
# Assigned Technician: Henry Mcdaniel
# Suitability: 2.00%
# Technician Capabilities: Adept at installing and maintaining building automation systems, including HVAC, lighting, and security controls.
#
# Task: Repair the broken air conditioning unit in the lobby.
# Assigned Technician: Wayne Bailey
# Suitability: 3.00%
# Technician Capabilities: Experienced in the maintenance of aquaculture systems, including fish tanks and breeding setups.
#
# Task: Fix the leaking water pipe in the basement.
# Assigned Technician: Amy Flores
# Suitability: 7.00%
# Technician Capabilities: Knowledgeable in the installation of solar water heating systems, providing sustainable hot water solutions.
#
# Task: Upgrade the electrical system in the office building.
# Assigned Technician: Henry Mcdaniel
# Suitability: 0.00%
# Technician Capabilities: Adept at installing and maintaining building automation systems, including HVAC, lighting, and security controls.
#
# Task: Install new carpeting in the conference room.
# Assigned Technician: Jordan Fletcher
# Suitability: 1.00%
# Technician Capabilities: Specialist in electronic circuit design, including prototyping, testing, and troubleshooting electronic systems.
#
# Task: Repair the faulty fire alarm system in the warehouse.
# Assigned Technician: Michael Barnes
# Suitability: 0.00%
# Technician Capabilities: Specialist in configuring and repairing smart home devices, including voice assistants and smart locks.
#
# Task: Service the backup generator in the utility room.
# Assigned Technician: Heather Perez
# Suitability: 1.00%
# Technician Capabilities: Experienced in telecommunications, including the installation and maintenance of telephony systems and internet connections.
#
# Task: Install new LED lighting in the parking lot.
# Assigned Technician: Wayne Bailey
# Suitability: 0.00%
# Technician Capabilities: Experienced in the maintenance of aquaculture systems, including fish tanks and breeding setups.
#
# Task: Fix the broken door lock in the storage area.
# Assigned Technician: Wayne Bailey
# Suitability: 6.00%
# Technician Capabilities: Experienced in the maintenance of aquaculture systems, including fish tanks and breeding setups.
#
# Task: Inspect and service the ventilation system in the factory.
# Assigned Technician: Ashley Rosales
# Suitability: 0.00%
# Technician Capabilities: Proficient in the setup and maintenance of aquariums, including freshwater and marine systems.

# %%
import joblib

# Train the model (as given in the initial code)
# ...

# Save the RandomForestClassifier model
joblib.dump(model, 'random_forest_model.joblib')

# Save the TfidfVectorizer
joblib.dump(vectorizer, 'tfidf_vectorizer.joblib')

# Save the LabelEncoder
joblib.dump(label_encoder, 'label_encoder.joblib')
# Out:
# ['label_encoder.joblib']
